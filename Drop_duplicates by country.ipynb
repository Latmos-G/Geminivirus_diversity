# %%
## Import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# Load the dataset and display the overview of first five rows

data  = pd.read_table('opunvirus.tsv')  # This read out the dataset
print(data.shape)
data.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (80, 48)
#      Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0  NC_055584.1  PRJNA485481                  NaN     COMPLETE         NaN
# 1   MN100038.1          NaN                  NaN     COMPLETE         NaN
# 2   MN100037.1          NaN                  NaN     COMPLETE         NaN
# 3   MN100036.1          NaN                  NaN     COMPLETE         NaN
# 4   MN100035.1          NaN                  NaN     COMPLETE         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0                 USA     North America               NaN
# 1                 USA     North America               NaN
# 2                 USA     North America               NaN
# 3                 USA     North America               NaN
# 4                 USA     North America               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# ...

# %%
dataUa = data.drop_duplicates(subset=['Geographic Location'])
dataUa
# Out:
#       Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0   NC_055584.1  PRJNA485481                  NaN     COMPLETE         NaN
# 75   MN099964.1          NaN                  NaN     COMPLETE         NaN
#
#    Geographic Location Geographic Region  Host Common Name  \
# 0                  USA     North America               NaN
# 75              Mexico     North America               NaN
#
#     Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                              NaN                                NaN  ...
# 75                             NaN                                NaN  ...
#
#     Virus Common Name  Virus Infraspecific Names Breed  \
# 0                 NaN                              NaN
# 75                NaN                              NaN
#
#     Virus Infraspecific Names Cultivar  Virus Infraspecific Names Ecotype  \
# 0                                  NaN                                NaN
# ...

# %%
dataUa.to_csv('opunvirusLocation.csv')

# %%
# Load the dataset and display the overview of first five rows

data1  = pd.read_table('capulavirus.tsv')  # This read out the dataset
print(data1.shape)
data1.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (265, 48)
#     Accession  BioProjects BioSample accession Completeness  Gene count  \
# 0  OR730838.1          NaN                 NaN     COMPLETE         NaN
# 1  OR233198.1          NaN                 NaN     COMPLETE         NaN
# 2  OP748371.1          NaN                 NaN     COMPLETE         NaN
# 3  ON859021.1          NaN                 NaN     COMPLETE         NaN
# 4  ON051015.1  PRJNA672730        SAMN16576454      PARTIAL         NaN
#
#    Geographic Location Geographic Region  Host Common Name  \
# 0                China              Asia               NaN
# 1             Viet Nam              Asia               NaN
# 2                China              Asia               NaN
# 3  China: ShanXi,Taigu              Asia               NaN
# 4                China              Asia               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# ...

# %%
data1U = data1.drop_duplicates(subset=['Geographic Location'])
data1U
# Out:
#        Accession  BioProjects BioSample accession Completeness  Gene count  \
# 0     OR730838.1          NaN                 NaN     COMPLETE         NaN
# 1     OR233198.1          NaN                 NaN     COMPLETE         NaN
# 3     ON859021.1          NaN                 NaN     COMPLETE         NaN
# 12   NC_075080.1  PRJNA485481                 NaN     COMPLETE         NaN
# 13   NC_038477.1  PRJNA485481                 NaN     COMPLETE         NaN
# ..           ...          ...                 ...          ...         ...
# 209   KT214398.1          NaN                 NaN      PARTIAL         NaN
# 213   KT214394.1          NaN                 NaN      PARTIAL         NaN
# 234   KT214373.1          NaN                 NaN     COMPLETE         NaN
# 249   KT214358.1          NaN                 NaN     COMPLETE         NaN
# 262   HF921477.1          NaN                 NaN     COMPLETE         NaN
#
# ...

# %%
data1U.to_csv('capulavirusLocation.csv')

# %%
# Load the dataset and display the overview of first five rows

data2  = pd.read_table('begomovirus.tsv')  # This read out the dataset
print(data2.shape)
data2.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (23525, 48)
# /tmp/ipykernel_5747/237841617.py:3: DtypeWarning: Columns (1,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2  = pd.read_table('begomovirus.tsv')  # This read out the dataset
#   Accession BioProjects BioSample accession Completeness  Gene count  \
# 0  Z86068.1         NaN                 NaN      PARTIAL         NaN
# 1  Z86067.1         NaN                 NaN      PARTIAL         NaN
# 2  Z83258.1         NaN                 NaN      PARTIAL         NaN
# 3  Z83257.1         NaN                 NaN      PARTIAL         NaN
# 4  Z83256.1         NaN                 NaN      PARTIAL         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0                 NaN               NaN               NaN
# 1                 NaN               NaN               NaN
# 2                 NaN            Africa               NaN
# 3                 NaN            Africa               NaN
# ...

# %%
data2U = data2.drop_duplicates(subset=['Geographic Location'])
data2U
# Out:
#         Accession BioProjects BioSample accession Completeness  Gene count  \
# 0        Z86068.1         NaN                 NaN      PARTIAL         NaN
# 84       U67926.2         NaN                 NaN      PARTIAL         NaN
# 120    PQ122803.1         NaN                 NaN     COMPLETE         NaN
# 121    PQ122802.1         NaN                 NaN     COMPLETE         NaN
# 122    PQ117598.1         NaN                 NaN     COMPLETE         NaN
# ...           ...         ...                 ...          ...         ...
# 23470  AB108832.1         NaN                 NaN      PARTIAL         NaN
# 23473  AB108829.1         NaN                 NaN      PARTIAL         NaN
# 23474  AB108828.1         NaN                 NaN      PARTIAL         NaN
# 23480  AB079765.1         NaN                 NaN     COMPLETE         NaN
# 23481  AB079689.1         NaN                 NaN     COMPLETE         NaN
#
# ...

# %%
data2U.to_csv('begomovirusLocation.csv')

# %%
# Load the dataset and display the overview of first five rows

data3  = pd.read_table('mastrevirus.tsv')  # This read out the dataset
print(data3.shape)
data3.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (2791, 48)
#   Accession BioProjects  BioSample accession Completeness  Gene count  \
# 0  Y11023.2         NaN                  NaN      PARTIAL         NaN
# 1  Y00514.1         NaN                  NaN      PARTIAL         NaN
# 2  X94330.1         NaN                  NaN     COMPLETE         NaN
# 3  X86705.1         NaN                  NaN      PARTIAL         NaN
# 4  X82104.1         NaN                  NaN      PARTIAL         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0                 NaN               NaN               NaN
# 1                 NaN               NaN               NaN
# 2             Reunion            Africa               NaN
# 3                 NaN               NaN               NaN
# 4                 NaN               NaN               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# ...

# %%
data3U = data3.drop_duplicates(subset=['Geographic Location'])
data3U
# Out:
#        Accession BioProjects  BioSample accession Completeness  Gene count  \
# 0       Y11023.2         NaN                  NaN      PARTIAL         NaN
# 2       X94330.1         NaN                  NaN     COMPLETE         NaN
# 30    PQ034624.1         NaN                  NaN      PARTIAL         NaN
# 31    PP992780.1         NaN                  NaN     COMPLETE         NaN
# 54    PP840304.1         NaN                  NaN     COMPLETE         NaN
# ...          ...         ...                  ...          ...         ...
# 2686  AM747816.1         NaN                  NaN      PARTIAL         NaN
# 2706  AM491474.1         NaN                  NaN      PARTIAL         NaN
# 2708  AM411652.1         NaN                  NaN      PARTIAL         NaN
# 2718  AM040733.1         NaN                  NaN     COMPLETE         NaN
# 2726  AJ811960.1         NaN                  NaN      PARTIAL         NaN
#
# ...

# %%
data3U.to_csv('mastrevirusLocation.csv')

# %%
# Load the dataset and display the overview of first five rows

data4  = pd.read_table('topilevirus.tsv')  # This read out the dataset
print(data4.shape)
data4.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (7, 48)
#      Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0  NC_076213.1  PRJNA485481                  NaN     COMPLETE         NaN
# 1  NC_036591.1  PRJNA485481                  NaN     COMPLETE         NaN
# 2   MT135209.1          NaN                  NaN     COMPLETE         NaN
# 3   MH539677.1          NaN                  NaN     COMPLETE         NaN
# 4   MG491197.1          NaN                  NaN     COMPLETE         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0           Argentina     South America               NaN
# 1           Argentina     South America               NaN
# 2              Brazil     South America               NaN
# 3              Brazil     South America               NaN
# 4           Argentina     South America               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# ...

# %%
data4U = data4.drop_duplicates(subset=['Geographic Location'])
data4U
# Out:
#      Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0  NC_076213.1  PRJNA485481                  NaN     COMPLETE         NaN
# 2   MT135209.1          NaN                  NaN     COMPLETE         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0           Argentina     South America               NaN
# 2              Brazil     South America               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# 2                             NaN                                NaN  ...
#
#    Virus Common Name  Virus Infraspecific Names Breed  \
# 0                NaN                              NaN
# 2                NaN                              NaN
#
#    Virus Infraspecific Names Cultivar  Virus Infraspecific Names Ecotype  \
# 0                                 NaN                                NaN
# ...

# %%
data4U.to_csv('topilevirusLocation.csv')

# %%
# Load the dataset and display the overview of first five rows

data5  = pd.read_table('topocuvirus.tsv')  # This read out the dataset
print(data5.shape)
data5.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (6, 48)
#      Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0     X84735.1          NaN                  NaN      PARTIAL         NaN
# 1   OR428175.1          NaN                  NaN      PARTIAL         NaN
# 2   OR428174.1          NaN                  NaN      PARTIAL         NaN
# 3   OR428173.1          NaN                  NaN      PARTIAL         NaN
# 4  NC_003825.1  PRJNA485481                  NaN     COMPLETE         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0                 NaN               NaN               NaN
# 1               China              Asia               NaN
# 2               China              Asia               NaN
# 3               China              Asia               NaN
# 4                 NaN               NaN               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# ...

# %%
data5U = data5.drop_duplicates(subset=['Geographic Location'])
data5U
# Out:
#     Accession BioProjects  BioSample accession Completeness  Gene count  \
# 0    X84735.1         NaN                  NaN      PARTIAL         NaN
# 1  OR428175.1         NaN                  NaN      PARTIAL         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0                 NaN               NaN               NaN
# 1               China              Asia               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# 1                             NaN                                NaN  ...
#
#    Virus Common Name  Virus Infraspecific Names Breed  \
# 0                NaN                              NaN
# 1                NaN                              NaN
#
#    Virus Infraspecific Names Cultivar  Virus Infraspecific Names Ecotype  \
# 0                                 NaN                                NaN
# ...

# %%
data5U.to_csv('topocuvirusLocation.csv')

# %%
# Load the dataset and display the overview of first five rows

data6  = pd.read_table('curtovirus.tsv')  # This read out the dataset
print(data6.shape)
data6.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (385, 48)
#   Accession BioProjects BioSample accession Completeness  Gene count  \
# 0  X97203.1         NaN                 NaN      PARTIAL         NaN
# 1  U57490.1         NaN                 NaN      PARTIAL         NaN
# 2  U56975.1         NaN                 NaN     COMPLETE         NaN
# 3  U49907.1         NaN                 NaN      PARTIAL         NaN
# 4  U02311.1         NaN                 NaN     COMPLETE         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0                 NaN               NaN               NaN
# 1                 NaN               NaN               NaN
# 2                 NaN               NaN               NaN
# 3                 NaN               NaN               NaN
# 4                 NaN               NaN               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# ...

# %%
data6U = data6.drop_duplicates(subset=['Geographic Location'])
data6U
# Out:
#       Accession  BioProjects BioSample accession Completeness  Gene count  \
# 0      X97203.1          NaN                 NaN      PARTIAL         NaN
# 5    PP498706.1          NaN                 NaN     COMPLETE         NaN
# 6    OR698904.1          NaN                 NaN      PARTIAL         NaN
# 8    OR698902.1          NaN                 NaN      PARTIAL         NaN
# 10   OR698900.1          NaN                 NaN      PARTIAL         NaN
# 11   OR451659.1          NaN                 NaN      PARTIAL         NaN
# 14   OR451656.1          NaN                 NaN      PARTIAL         NaN
# 17   OR451653.1          NaN                 NaN      PARTIAL         NaN
# 20   OR451650.1          NaN                 NaN      PARTIAL         NaN
# 64   OR451606.1          NaN                 NaN      PARTIAL         NaN
# 79   OR101700.1          NaN                 NaN      PARTIAL         NaN
# 85   OQ628293.1          NaN                 NaN     COMPLETE         NaN
# ...

# %%
data6U.to_csv('curtovirusLocation.csv')

# %%
# Load the dataset and display the overview of first five rows

data7  = pd.read_table('becurtovirus.tsv')  # This read out the dataset
print(data7.shape)
data7.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (140, 48)
#     Accession BioProjects  BioSample accession Completeness  Gene count  \
# 0  PP789055.1         NaN                  NaN     COMPLETE         NaN
# 1  PP573857.1         NaN                  NaN     COMPLETE         NaN
# 2  OR451599.1         NaN                  NaN      PARTIAL         NaN
# 3  OR451598.1         NaN                  NaN      PARTIAL         NaN
# 4  OR451597.1         NaN                  NaN      PARTIAL         NaN
#
#        Geographic Location Geographic Region  Host Common Name  \
# 0                     Iran              Asia               NaN
# 1                     Iran              Asia               NaN
# 2  USA: Idaho, TwinFallsCo     North America               NaN
# 3    USA: Idaho, BinghamCo     North America               NaN
# 4     USA: Idaho, ElmoreCo     North America               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# ...

# %%
data7U = data7.drop_duplicates(subset=['Geographic Location'])  # Remove duplicates in the geographical location
data7U
# Out:
#        Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0     PP789055.1          NaN                  NaN     COMPLETE         NaN
# 2     OR451599.1          NaN                  NaN      PARTIAL         NaN
# 3     OR451598.1          NaN                  NaN      PARTIAL         NaN
# 4     OR451597.1          NaN                  NaN      PARTIAL         NaN
# 8     OR451593.1          NaN                  NaN      PARTIAL         NaN
# 9     OQ703946.1          NaN                  NaN      PARTIAL         NaN
# 10    ON014774.1          NaN                  NaN     COMPLETE         NaN
# 11    ON014773.1          NaN                  NaN     COMPLETE         NaN
# 14    ON014770.1          NaN                  NaN     COMPLETE         NaN
# 15    ON014769.1          NaN                  NaN     COMPLETE         NaN
# 16    ON014768.1          NaN                  NaN     COMPLETE         NaN
# ...

# %%
data7U.to_csv('becurtovirusLocation.csv')

# %%
# Load the dataset and display the overview of first five rows

data8  = pd.read_table('turncurtovirus.tsv')  # This read out the dataset
print(data8.shape)
data8.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (72, 48)
#      Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0   PP573856.1          NaN                  NaN     COMPLETE         NaN
# 1  NC_076020.1  PRJNA485481                  NaN     COMPLETE         NaN
# 2  NC_029117.1  PRJNA485481                  NaN     COMPLETE         NaN
# 3  NC_014324.1  PRJNA485481                  NaN     COMPLETE         NaN
# 4   MT041697.1          NaN                  NaN     COMPLETE         NaN
#
#     Geographic Location Geographic Region  Host Common Name  \
# 0         Iran: Markazi              Asia               NaN
# 1      Pakistan: Layyah              Asia               NaN
# 2                  Iran              Asia               NaN
# 3                  Iran              Asia               NaN
# 4  Iran: Kerman, Jiroft              Asia               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# ...

# %%
data8U = data8.drop_duplicates(subset=['Geographic Location'])  # Remove duplicates in the geographical location
data8U
# Out:
#       Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0    PP573856.1          NaN                  NaN     COMPLETE         NaN
# 1   NC_076020.1  PRJNA485481                  NaN     COMPLETE         NaN
# 2   NC_029117.1  PRJNA485481                  NaN     COMPLETE         NaN
# 4    MT041697.1          NaN                  NaN     COMPLETE         NaN
# 5    MT041696.1          NaN                  NaN     COMPLETE         NaN
# 7    MT041694.1          NaN                  NaN     COMPLETE         NaN
# 8    MT041693.1          NaN                  NaN     COMPLETE         NaN
# 11   MH595454.1          NaN                  NaN     COMPLETE         NaN
# 23   MF536416.1          NaN                  NaN     COMPLETE         NaN
# 52   KC108906.1          NaN                  NaN     COMPLETE         NaN
# 54   KC108904.1          NaN                  NaN     COMPLETE         NaN
# ...

# %%
data8U.to_csv('turncurtovirusLocation.csv')  # save the updated file into a csv file

# %%
# Load the dataset and display the overview of first five rows

data9  = pd.read_table('maldovirus.tsv')  # This read out the dataset
print(data9.shape)
data9.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (51, 48)
#     Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0  PQ106730.1          NaN                  NaN     COMPLETE         NaN
# 1  PP397181.1          NaN                  NaN     COMPLETE         NaN
# 2  OR364963.1          NaN                  NaN     COMPLETE         NaN
# 3  OR061051.1  PRJNA737529                  NaN      PARTIAL         NaN
# 4  OR061050.1  PRJNA737529                  NaN      PARTIAL         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0               China              Asia               NaN
# 1               China              Asia               NaN
# 2               China              Asia               NaN
# 3           Australia           Oceania               NaN
# 4           Australia           Oceania               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# ...

# %%
data9U = data9.drop_duplicates(subset=['Geographic Location'])  # Remove duplicates in the geographical location
data9U
# Out:
#       Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0    PQ106730.1          NaN                  NaN     COMPLETE         NaN
# 3    OR061051.1  PRJNA737529                  NaN      PARTIAL         NaN
# 5    OQ427641.1          NaN                  NaN      PARTIAL         NaN
# 6    ON868755.1          NaN                  NaN     COMPLETE         NaN
# 8   NC_037066.1  PRJNA485481                  NaN     COMPLETE         NaN
# 9   NC_031340.1  PRJNA485481                  NaN     COMPLETE         NaN
# 11   MZ488502.1          NaN                  NaN     COMPLETE         NaN
# 24   MK690474.1          NaN                  NaN     COMPLETE         NaN
# 25   MK336184.1          NaN                  NaN     COMPLETE         NaN
# 33   LC424098.1          NaN                  NaN     COMPLETE         NaN
# 39   KX570618.1          NaN                  NaN     COMPLETE         NaN
#
#    Geographic Location Geographic Region  Host Common Name  \
# ...

# %%
data9U.to_csv('maldovirusLocation.csv')  # save the updated file into a csv file

# %%
# Load the dataset and display the overview of first five rows

data10  = pd.read_table('grablovirus.tsv')  # This read out the dataset
print(data10.shape)
data10.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (352, 48)
#     Accession BioProjects  BioSample accession Completeness  Gene count  \
# 0  PP091647.1         NaN                  NaN      PARTIAL         NaN
# 1  PP091646.1         NaN                  NaN      PARTIAL         NaN
# 2  PP091645.1         NaN                  NaN      PARTIAL         NaN
# 3  PP091644.1         NaN                  NaN      PARTIAL         NaN
# 4  PP091643.1         NaN                  NaN      PARTIAL         NaN
#
#                        Geographic Location Geographic Region  \
# 0  Iran: Kashmar, Khorasan Razavi province              Asia
# 1  Iran: Kashmar, Khorasan Razavi province              Asia
# 2  Iran: Kashmar, Khorasan Razavi province              Asia
# 3  Iran: Kashmar, Khorasan Razavi province              Asia
# 4  Iran: Kashmar, Khorasan Razavi province              Asia
#
#    Host Common Name  Host Infraspecific Names Breed  \
# 0               NaN                             NaN
# ...

# %%
data10U = data10.drop_duplicates(subset=['Geographic Location'])  # Remove duplicates in the geographical location
data10U
# Out:
#        Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0     PP091647.1          NaN                  NaN      PARTIAL         NaN
# 6     OP597762.1          NaN                  NaN     COMPLETE         NaN
# 8     OP597760.1          NaN                  NaN     COMPLETE         NaN
# 15    OP434517.1          NaN                  NaN      PARTIAL         NaN
# 49    OM135587.1          NaN                  NaN     COMPLETE         NaN
# 51   NC_075437.1  PRJNA485481                  NaN     COMPLETE         NaN
# 55   NC_017918.2  PRJNA485481                  NaN     COMPLETE         NaN
# 59    MW273131.1          NaN                  NaN      PARTIAL         NaN
# 75    MK928386.1          NaN                  NaN     COMPLETE         NaN
# 83    MK789665.1          NaN                  NaN      PARTIAL         NaN
# 84    MK784175.1          NaN                  NaN      PARTIAL         NaN
# ...

# %%
data10U.to_csv('grablovirusLocation.csv')  # save the updated file into a csv file

# %%
# Load the dataset and display the overview of first five rows

data11  = pd.read_table('mulcrilevirus.tsv')  # This read out the dataset
print(data11.shape)
data11.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (40, 48)
#      Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0  NC_076464.1  PRJNA485481                  NaN     COMPLETE         NaN
# 1   MZ420375.1          NaN                  NaN      PARTIAL         NaN
# 2   MZ420374.1          NaN                  NaN      PARTIAL         NaN
# 3   MZ420373.1          NaN                  NaN      PARTIAL         NaN
# 4   MZ420372.1          NaN                  NaN      PARTIAL         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0               China              Asia               NaN
# 1               China              Asia               NaN
# 2               China              Asia               NaN
# 3               China              Asia               NaN
# 4               China              Asia               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# ...

# %%
data11U = data11.drop_duplicates(subset=['Geographic Location'])  # Remove duplicates in the geographical location
data11U
# Out:
#      Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0  NC_076464.1  PRJNA485481                  NaN     COMPLETE         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0               China              Asia               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
#
#    Virus Common Name  Virus Infraspecific Names Breed  \
# 0                NaN                              NaN
#
#    Virus Infraspecific Names Cultivar  Virus Infraspecific Names Ecotype  \
# 0                                 NaN                                NaN
#
#   Virus Infraspecific Names Isolate  Virus Infraspecific Names Sex  \
# 0                               NaN                            NaN
#
#    Virus Infraspecific Names Strain  \
# 0                               NaN
#
#                                        Virus Name  \
# ...

# %%
data11U.to_csv('mulcrilevirusLocation.csv')  # save the updated file into a csv file

# %%
# Load the dataset and display the overview of first five rows

data12  = pd.read_table('eragrovirus.tsv')  # This read out the dataset
print(data12.shape)
data12.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (7, 48)
#      Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0  NC_012664.1  PRJNA485481                  NaN     COMPLETE         NaN
# 1   FJ665634.1          NaN                  NaN     COMPLETE         NaN
# 2   FJ665633.1          NaN                  NaN     COMPLETE         NaN
# 3   FJ665632.1          NaN                  NaN     COMPLETE         NaN
# 4   FJ665631.1          NaN                  NaN     COMPLETE         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0        South Africa            Africa               NaN
# 1        South Africa            Africa               NaN
# 2        South Africa            Africa               NaN
# 3        South Africa            Africa               NaN
# 4        South Africa            Africa               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# ...

# %%
data12U = data12.drop_duplicates(subset=['Geographic Location'])  # Remove duplicates in the geographical location
data12U
# Out:
#      Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0  NC_012664.1  PRJNA485481                  NaN     COMPLETE         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0        South Africa            Africa               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
#
#    Virus Common Name  Virus Infraspecific Names Breed  \
# 0                NaN                              NaN
#
#    Virus Infraspecific Names Cultivar  Virus Infraspecific Names Ecotype  \
# 0                                 NaN                                NaN
#
#   Virus Infraspecific Names Isolate  Virus Infraspecific Names Sex  \
# 0                               NaN                            NaN
#
#    Virus Infraspecific Names Strain                       Virus Name  \
# 0                               NaN  Eragrostis curvula streak virus
# ...

# %%
data12U.to_csv('eragrovirusLocation.csv')  # save the updated file into a csv file

# %%
# Load the dataset and display the overview of first five rows

data13  = pd.read_table('citlodavirus.tsv')  # This read out the dataset
print(data13.shape)
data13.head()  # Display first 5 rows of the loaded dataset for quick observation
# Out:
# (105, 48)
#     Accession BioProjects  BioSample accession Completeness  Gene count  \
# 0  OP374189.1         NaN                  NaN     COMPLETE         NaN
# 1  ON063223.1         NaN                  NaN     COMPLETE         NaN
# 2  ON063222.1         NaN                  NaN     COMPLETE         NaN
# 3  ON063221.1         NaN                  NaN     COMPLETE         NaN
# 4  OL514016.1         NaN                  NaN     COMPLETE         NaN
#
#   Geographic Location Geographic Region  Host Common Name  \
# 0               China              Asia               NaN
# 1               China              Asia               NaN
# 2               China              Asia               NaN
# 3               China              Asia               NaN
# 4               China              Asia               NaN
#
#    Host Infraspecific Names Breed  Host Infraspecific Names Cultivar  ...  \
# 0                             NaN                                NaN  ...
# ...

# %%
data13U = data13.drop_duplicates(subset=['Geographic Location'])  # Remove duplicates in the geographical location
data13U
# Out:
#       Accession  BioProjects  BioSample accession Completeness  Gene count  \
# 0    OP374189.1          NaN                  NaN     COMPLETE         NaN
# 9   NC_040706.1  PRJNA485481                  NaN     COMPLETE         NaN
# 10  NC_018151.1          NaN                  NaN     COMPLETE         NaN
# 11   MW413555.1          NaN                  NaN     COMPLETE         NaN
# 44   MT492447.1          NaN                  NaN      PARTIAL         NaN
# 52   MN509442.1          NaN                  NaN     COMPLETE         NaN
#
#    Geographic Location Geographic Region  Host Common Name  \
# 0                China              Asia               NaN
# 9               Brazil     South America               NaN
# 10              Turkey              Asia               NaN
# 11                 NaN               NaN               NaN
# 44       Turkey: Adana              Asia               NaN
# 52            Thailand              Asia               NaN
#
# ...

# %%
data13U.to_csv('citlodavirusLocation.csv')  # save the updated file into a csv file
